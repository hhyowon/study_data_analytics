# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('font',family='Malgun Gothic')   #한글처리
import seaborn as sns

# %% [markdown]
# ### load datasets

# %%
import pandas as pd

# %%
df_TOCC = pd.read_csv('../../datasets/TypeOfContractChannel.csv')
df_TOCC[:3]
# Out:
#          id type_of_contract type_of_contract2 channel    datetime  Term  \
# 0  66758234               렌탈            Normal  서비스 방문  2019-10-20    60
# 1  66755948               렌탈  Extension_Rental  서비스 방문  2019-10-20    60
# 2  66756657               렌탈            Normal  홈쇼핑/방송  2019-10-20    60
#
#   payment_type product  amount state  overdue_count overdue  credit rating  \
# 0          CMS      K1   96900  계약확정              0      없음            9.0
# 1         카드이체      K1  102900  계약확정              0      없음            2.0
# 2          CMS      K1   96900  계약확정              0      없음            8.0
#
#     bank cancellation   age  Mileage
# 0  새마을금고           정상  43.0   1862.0
# 1   현대카드           정상  62.0   2532.0
# 2   우리은행           정상  60.0   2363.0

# %%
df_TOCC.value_counts()
# Out:
# id        type_of_contract  type_of_contract2  channel  datetime    Term  payment_type  product  amount  state  overdue_count  overdue  credit rating  bank  cancellation  age   Mileage
# 25732056  렌탈                Normal             영업방판     2020-01-27  60    CMS           K1       96900   계약확정   0              없음       7.0            기업은행  정상            37.0  1669.0     1
# 66775935  렌탈                Normal             홈쇼핑/방송   2019-12-03  60    카드이체          K1       105900  계약확정   0              없음       1.0            롯데카드  정상            49.0  1950.0     1
# 66775922  렌탈                Promotion          서비스 방문   2019-12-04  36    CMS           K2       102900  계약확정   0              없음       3.0            농협은행  정상            48.0  1940.0     1
# 66775924  렌탈                Normal             서비스 방문   2019-12-05  60    CMS           K1       96900   계약확정   0              없음       4.0            국민은행  정상            34.0  1613.0     1
# ...

# %% [markdown]
# ### 단일 변수

# %%
df_TOCC.describe(include=object) #범주형 (유니크보기 , 카운트대비 유니크가 굉장히 작으면 대부분벙주형)
# Out:
#        type_of_contract type_of_contract2 channel    datetime payment_type  \
# count             51300             51303   51304       51304        51304
# unique                2                 9      20         101            5
# top                  렌탈         Promotion  서비스 방문  2019-10-29          CMS
# freq              46481             15811   15186         817        32825
#
#        product  state overdue   bank cancellation
# count    51303  51304   51302  48544        51279
# unique       6      4       2     46            2
# top         K1   계약확정      없음   국민은행           정상
# freq     39134  50350   49112   9901        50372

# %%
df_TOCC.describe(include=object).columns
# Out:
# Index(['type_of_contract', 'type_of_contract2', 'channel', 'datetime',
#        'payment_type', 'product', 'state', 'overdue', 'bank', 'cancellation'],
#       dtype='object')

# %% [markdown]
# #### 범주형 : 주로 문자 , 항목으로 구성

# %%
df_TOCC['type_of_contract'].value_counts()
# Out:
# 렌탈     46481
# 멤버십     4819
# Name: type_of_contract, dtype: int64

# %%
sns.countplot(data=df_TOCC, x='type_of_contract')
plt.title("계약 종료")
plt.show()

# %%
df_TOCC['type_of_contract2'].value_counts()
# Out:
# Promotion           15811
# Normal              15324
# Package             10184
# Extension_Rental     4975
# TAS                  2627
# TA2                  2087
# Group                 190
# TA3                    92
# TA1                    13
# Name: type_of_contract2, dtype: int64

# %%
#sns.countplot(data=df_TOCC, x='type_of_contract2',hue='product')  #다변수일때
sns.countplot(data=df_TOCC, y='type_of_contract2') 
plt.show()

# %%
df_TOCC['bank'].value_counts()
# Out:
# 국민은행         9901
# 롯데카드         9518
# 농협은행         6278
# 신한은행         3522
# 우리은행         3386
# 기업은행         1963
# 신한카드         1533
# 하나은행         1446
# 국민카드         1311
# BC카드         1264
# 새마을금고         964
# 부산은행          888
# 삼성카드          884
# 현대카드          876
# 대구은행          746
# 우체국           717
# 외환은행          586
# 외환카드          530
# 경남은행          442
# SC제일은행        439
# 광주은행          347
# 신협중앙회         341
# 전북은행          195
# 씨티은행          162
# 수협중앙회         160
# 제주은행           40
# 유안타증권          27
# 산업은행           23
# 현대증권           11
# 삼성증권            7
# 하나SK            6
# 미래에셋증권          5
# NH농협카드          4
# 한국투자증권          4
# 신한금융투자          4
# 우리카드            3
# 대우증권            2
# 하이투자증권          1
# 메리츠종합금융증권       1
# 수협카드            1
# 상호저축은행          1
# SK증권            1
# 하나대투증권          1
# 산림조합중앙회         1
# 대신증권            1
# 씨티카드            1
# Name: bank, dtype: int64

# %%
sns.countplot(data=df_TOCC, y='bank') 
plt.show()

# %%
# 거래 은행 중 상위 7개 확인 (bank columns -> 항목 series -> index 추출 -> list로 변환 -> slicing 7개
order_list = df_TOCC['bank'].value_counts().index.to_list()[:7]
order_list
# Out:
# ['국민은행', '롯데카드', '농협은행', '신한은행', '우리은행', '기업은행', '신한카드']

# %%
# sns.countplot(data=df_TOCC, y='bank',order=['국민은행','롯데카드','BC카드']) 
sns.countplot(data=df_TOCC, y='bank',order=order_list) 
plt.show()

# %% [markdown]
# #### 연속형 : 범주형이 아닌 것

# %%
df_TOCC.describe()
# Out:
#                  id          Term         amount  overdue_count  \
# count  5.130400e+04  51304.000000   51304.000000   51304.000000
# mean   6.266457e+07     55.638527   93994.980021       0.161040
# std    1.216115e+07     12.010117   15305.147334       1.122356
# min    2.568798e+07     12.000000   54603.000000      -1.000000
# 25%    6.643149e+07     60.000000   81900.000000       0.000000
# 50%    6.676578e+07     60.000000   96900.000000       0.000000
# 75%    6.678161e+07     60.000000   98400.000000       0.000000
# max    6.696986e+07     60.000000  215700.000000      15.000000
#
#        credit rating           age       Mileage
# count   42521.000000  40509.000000  40509.000000
# mean        3.428894     46.608285   1967.922412
# std         2.213590     13.465977    436.707329
# min         0.000000     20.000000    872.000000
# 25%         1.000000     37.000000   1646.000000
# 50%         3.000000     46.000000   1946.000000
# ...

# %%
sns.histplot(data=df_TOCC,x='age',kde=True,hue='type_of_contract2')
plt.show()

# %%
sns.boxplot(data=df_TOCC,x='age')
# Out:
# <Axes: xlabel='age'>

# %%
df_TOCC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51304 entries, 0 to 51303
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 51304 non-null  int64
#  1   type_of_contract   51300 non-null  object
#  2   type_of_contract2  51303 non-null  object
#  3   channel            51304 non-null  object
#  4   datetime           51304 non-null  object
#  5   Term               51304 non-null  int64
#  6   payment_type       51304 non-null  object
#  7   product            51303 non-null  object
#  8   amount             51304 non-null  int64
#  9   state              51304 non-null  object
#  10  overdue_count      51304 non-null  int64
#  11  overdue            51302 non-null  object
#  12  credit rating      42521 non-null  float64
#  13  bank               48544 non-null  object
#  14  cancellation       51279 non-null  object
#  15  age                40509 non-null  float64
# ...

# %% [markdown]
# ### 다변수

# %% [markdown]
# #### X(설명변수) / Y(목표변수)  : 범주형 / 연속형

# %%
df_TOCC.columns
# Out:
# Index(['id', 'type_of_contract', 'type_of_contract2', 'channel', 'datetime',
#        'Term', 'payment_type', 'product', 'amount', 'state', 'overdue_count',
#        'overdue', 'credit rating', 'bank', 'cancellation', 'age', 'Mileage'],
#       dtype='object')

# %%
df_TOCC['amount'].describe()
# Out:
# count     51304.000000
# mean      93994.980021
# std       15305.147334
# min       54603.000000
# 25%       81900.000000
# 50%       96900.000000
# 75%       98400.000000
# max      215700.000000
# Name: amount, dtype: float64

# %%
# sns.barplot(data=df_TOCC,x='channel',y='amount') # 기본 평균
sns.barplot(data=df_TOCC,x='channel',y='amount',estimator=sum) # 기본 총합
plt.show()

# %%
df_TOCC_sum = pd.pivot_table(data=df_TOCC, index='channel', values='amount', aggfunc=sum)
df_TOCC_bottom_list = df_TOCC_sum.sort_values(by='amount', ascending=False).iloc[-7:].index.to_list()

# %%
sns.barplot(data=df_TOCC,x='channel', y='amount', estimator=sum,order=df_TOCC_bottom_list) # 하위 7개 순위 표현
# Out:
# <Axes: xlabel='channel', ylabel='amount'>

# %%
sns.barplot(data=df_TOCC,x='channel', y='amount', estimator=sum,order=df_TOCC_bottom_list,hue='type_of_contract') # 하위 7개 순위 표현
# Out:
# <Axes: xlabel='channel', ylabel='amount'>

# %% [markdown]
# ### Quest1 : 230814
# - x='product',y='amount'
# - order by : top 6(amount)
# - hue='type_of_contract2'

# %%
df_TOCC['amount'].describe()
# Out:
# count     51304.000000
# mean      93994.980021
# std       15305.147334
# min       54603.000000
# 25%       81900.000000
# 50%       96900.000000
# 75%       98400.000000
# max      215700.000000
# Name: amount, dtype: float64

# %%
# sns.barplot(data=df_TOCC,x='product',y='amount') # 기본 평균
sns.barplot(data=df_TOCC,x='product',y='amount',estimator=sum) # 기본 총합
plt.show()

# %%
df_TOCC_sum = pd.pivot_table(data=df_TOCC, index='product', values='amount', aggfunc=sum)
df_TOCC_top_list = df_TOCC_sum.sort_values(by='amount', ascending=False).iloc[:3].index.to_list()

# %%
sns.barplot(data=df_TOCC,x='product', y='amount', estimator=sum,order=df_TOCC_top_list) # 상위 3개 순위 표현
# Out:
# <Axes: xlabel='product', ylabel='amount'>

# %%
sns.barplot(data=df_TOCC,x='product', y='amount', estimator=sum,order=df_TOCC_top_list,hue='type_of_contract2') # 상위 3개 순위 표현
# Out:
# <Axes: xlabel='product', ylabel='amount'>
