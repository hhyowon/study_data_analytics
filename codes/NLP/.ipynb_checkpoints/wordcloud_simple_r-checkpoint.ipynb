# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\04-04\anaconda3\lib\site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\04-04\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\04-04\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\04-04\anaconda3\lib\site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\04-04\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\04-04\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\04-04\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\04-04\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\04-04\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\04-04\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\04-04\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\04-04\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from wordcloud import WordCloud

# %%
# 한글 문장 리스트
sentences = [
    "오늘 날씨가 좋아서 나들이 가고 싶다.",
    "이 영화는 정말 재미있었어요.",
    "맛있는 음식을 먹으러 갈까요?",
    "운동을 하면 건강에 좋아지는 것 같아요.",
    "공부하기 싫어서 미루고 있어요.",
    "여행 계획을 세우고 있는데 어디로 갈까요?",
    "좋은 책을 읽으면 마음이 편안해져요.",
    "오늘은 친구들과 만나서 재미있게 놀았어요.",
    "새로운 언어를 배우는 것은 어려워도 흥미로워요.",
    "주말에 가족들과 함께 시간을 보내기로 했습니다."
]

sentences = [
    "이 영화는 놀라운 것이었습니다! 흥미진진한 줄거리였어요.",
    "나는 영화 전체 동안 웃을 수 없었습니다. 정말 웃기다!",
    "이 영화의 시네마토그래피는 최고 수준입니다. 놀라운 시각 효과!",
    "나는 이 영화의 연기를 최상으로 생각하지 않았어요.",
    "감독은 이 책의 본질을 이번 영화에 완벽하게 담아냈습니다.",
    "진정한 걸작! 나는 확실히 다시 볼 것이다.",
    "특수 효과는 놀랍습니다. 시각적인 스펙터클!",
    "스토리는 좀 혼란스러웠지만, 연기는 뛰어났어요.",
    "나는 이 영화에 실망했습니다. 기대에 부응하지 못했어요.",
    "이 영화는 내가 몇 년 동안 본 최고의 영화 중 하나에요. 강력 추천!"
]

# %% [markdown]
# ## 자연어 처리 위한 단어 생성

# %%
# "맛있는 음식을 먹으러 갈까요?" -> 4개
#  "여행 계획을 세우고 있는데 어디로 갈까요?", -> 6개
text = ''.join(sentences)
text
# Out:
# '이 영화는 놀라운 것이었습니다! 흥미진진한 줄거리였어요.나는 영화 전체 동안 웃을 수 없었습니다. 정말 웃기다!이 영화의 시네마토그래피는 최고 수준입니다. 놀라운 시각 효과!나는 이 영화의 연기를 최상으로 생각하지 않았어요.감독은 이 책의 본질을 이번 영화에 완벽하게 담아냈습니다.진정한 걸작! 나는 확실히 다시 볼 것이다.특수 효과는 놀랍습니다. 시각적인 스펙터클!스토리는 좀 혼란스러웠지만, 연기는 뛰어났어요.나는 이 영화에 실망했습니다. 기대에 부응하지 못했어요.이 영화는 내가 몇 년 동안 본 최고의 영화 중 하나에요. 강력 추천!'

# %%
text_split = text.split()   #split기본' '
text_split
# Out:
# ['이',
#  '영화는',
#  '놀라운',
#  '것이었습니다!',
#  '흥미진진한',
#  '줄거리였어요.나는',
#  '영화',
#  '전체',
#  '동안',
#  '웃을',
#  '수',
#  '없었습니다.',
#  '정말',
#  '웃기다!이',
#  '영화의',
#  '시네마토그래피는',
#  '최고',
#  '수준입니다.',
#  '놀라운',
#  '시각',
#  '효과!나는',
#  '이',
#  '영화의',
#  '연기를',
#  '최상으로',
#  '생각하지',
#  '않았어요.감독은',
#  '이',
#  '책의',
#  '본질을',
#  '이번',
#  '영화에',
#  '완벽하게',
#  '담아냈습니다.진정한',
#  '걸작!',
#  '나는',
#  '확실히',
#  '다시',
#  '볼',
#  '것이다.특수',
#  '효과는',
#  '놀랍습니다.',
#  '시각적인',
#  '스펙터클!스토리는',
#  '좀',
#  '혼란스러웠지만,',
#  '연기는',
#  '뛰어났어요.나는',
#  '이',
#  '영화에',
#  '실망했습니다.',
#  '기대에',
#  '부응하지',
#  '못했어요.이',
#  '영화는',
#  '내가',
#  '몇',
#  '년',
#  '동안',
#  '본',
#  '최고의',
#  '영화',
#  '중',
#  '하나에요.',
#  '강력',
#  '추천!']

# %%
from collections import Counter
Counter(text_split)
# Out:
# Counter({'이': 4,
#          '영화는': 2,
#          '놀라운': 2,
#          '것이었습니다!': 1,
#          '흥미진진한': 1,
#          '줄거리였어요.나는': 1,
#          '영화': 2,
#          '전체': 1,
#          '동안': 2,
#          '웃을': 1,
#          '수': 1,
#          '없었습니다.': 1,
#          '정말': 1,
#          '웃기다!이': 1,
#          '영화의': 2,
#          '시네마토그래피는': 1,
#          '최고': 1,
#          '수준입니다.': 1,
#          '시각': 1,
#          '효과!나는': 1,
#          '연기를': 1,
#          '최상으로': 1,
#          '생각하지': 1,
#          '않았어요.감독은': 1,
#          '책의': 1,
#          '본질을': 1,
#          '이번': 1,
#          '영화에': 2,
#          '완벽하게': 1,
#          '담아냈습니다.진정한': 1,
#          '걸작!': 1,
#          '나는': 1,
#          '확실히': 1,
#          '다시': 1,
#          '볼': 1,
#          '것이다.특수': 1,
#          '효과는': 1,
#          '놀랍습니다.': 1,
#          '시각적인': 1,
#          '스펙터클!스토리는': 1,
#          '좀': 1,
#          '혼란스러웠지만,': 1,
#          '연기는': 1,
#          '뛰어났어요.나는': 1,
#          '실망했습니다.': 1,
#          '기대에': 1,
#          '부응하지': 1,
#          '못했어요.이': 1,
#          '내가': 1,
#          '몇': 1,
#          '년': 1,
#          '본': 1,
#          '최고의': 1,
#          '중': 1,
#          '하나에요.': 1,
#          '강력': 1,
#          '추천!': 1})

# %%
# 한글 폰트 경로 설정 (Windows 환경에 맞게 경로 수정)
font_path = 'C:/Windows/Fonts/malgun.ttf'

wordCloud = WordCloud(font_path=font_path, background_color='white')
wordCloud.generate_from_text(text)

# %%
wordCloud.words_
# Out:
# {'이': 1.0,
#  '나는': 0.6666666666666666,
#  '영화는': 0.3333333333333333,
#  '놀라운': 0.3333333333333333,
#  '영화': 0.3333333333333333,
#  '동안': 0.3333333333333333,
#  '영화의': 0.3333333333333333,
#  '영화에': 0.3333333333333333,
#  '것이었습니다': 0.16666666666666666,
#  '흥미진진한': 0.16666666666666666,
#  '줄거리였어요': 0.16666666666666666,
#  '전체': 0.16666666666666666,
#  '웃을': 0.16666666666666666,
#  '수': 0.16666666666666666,
#  '없었습니다': 0.16666666666666666,
#  '정말': 0.16666666666666666,
#  '웃기다': 0.16666666666666666,
#  '시네마토그래피는': 0.16666666666666666,
#  '최고': 0.16666666666666666,
#  '수준입니다': 0.16666666666666666,
#  '시각': 0.16666666666666666,
#  '효과': 0.16666666666666666,
#  '연기를': 0.16666666666666666,
#  '최상으로': 0.16666666666666666,
#  '생각하지': 0.16666666666666666,
#  '않았어요': 0.16666666666666666,
#  '감독은': 0.16666666666666666,
#  '책의': 0.16666666666666666,
#  '본질을': 0.16666666666666666,
#  '이번': 0.16666666666666666,
#  '완벽하게': 0.16666666666666666,
#  '담아냈습니다': 0.16666666666666666,
#  '진정한': 0.16666666666666666,
#  '걸작': 0.16666666666666666,
#  '확실히': 0.16666666666666666,
#  '다시': 0.16666666666666666,
#  '볼': 0.16666666666666666,
#  '것이다': 0.16666666666666666,
#  '특수': 0.16666666666666666,
#  '효과는': 0.16666666666666666,
#  '놀랍습니다': 0.16666666666666666,
#  '시각적인': 0.16666666666666666,
#  '스펙터클': 0.16666666666666666,
#  '스토리는': 0.16666666666666666,
#  '좀': 0.16666666666666666,
#  '혼란스러웠지만': 0.16666666666666666,
#  '연기는': 0.16666666666666666,
#  '뛰어났어요': 0.16666666666666666,
#  '실망했습니다': 0.16666666666666666,
#  '기대에': 0.16666666666666666,
#  '부응하지': 0.16666666666666666,
#  '못했어요': 0.16666666666666666,
#  '내가': 0.16666666666666666,
#  '몇': 0.16666666666666666,
#  '년': 0.16666666666666666,
#  '본': 0.16666666666666666,
#  '최고의': 0.16666666666666666,
#  '중': 0.16666666666666666,
#  '하나에요': 0.16666666666666666,
#  '강력': 0.16666666666666666,
#  '추천': 0.16666666666666666}

# %%
import matplotlib.pyplot as plt
plt.imshow(wordCloud)
plt.axis('off')
plt.show()
