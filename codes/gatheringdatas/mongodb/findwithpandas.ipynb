# %%
# %conda install pymongo

# %%
import pymongo as mg
import pandas as pd

# %%
mg.__version__
# Out:
# '3.12.0'

# %%
client = mg.MongoClient(host='mongodb://localhost:27017')

# %%
database = client['db_NHIS']

# %%
collection = database['NSC2_BND']

# %%
cursor = collection.find({})

# %%
list_BND = list(cursor)

# %%
list_BND
# Out:
# [{'_id': ObjectId('64d2fd08ec72f175b12b7df2'),
#   'RN_INDI': 294364,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 200707,
#   'COD1': 'T08-T14',
#   'COD2': 'W00-W19'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7df3'),
#   'RN_INDI': 646257,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 200805,
#   'COD1': 'A15-A19'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7df4'),
#   'RN_INDI': 733575,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201309,
#   'COD1': 'G30'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7df5'),
#   'RN_INDI': 966199,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201409,
#   'COD1': 'J69'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7df6'),
#   'RN_INDI': 972598,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201205,
#   'COD1': 'C44'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7df7'),
#   'RN_INDI': 979888,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201101,
#   'COD1': 'R54'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7df8'),
#   'RN_INDI': 991645,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201504,
#   'COD1': 'K92'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7df9'),
#   'RN_INDI': 1002735,
#   'BTH_YYYY': 1922,
#   'DTH_YYYYMM': 200912,
#   'COD1': 'I63'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7dfa'),
#   'RN_INDI': 81830,
#   'BTH_YYYY': 1923,
#   'DTH_YYYYMM': 201106,
#   'COD1': 'K65'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7dfb'),
#   'RN_INDI': 126693,
#   'BTH_YYYY': 1924,
#   'DTH_YYYYMM': 201602,
#   'COD1': 'C23'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7dfc'),
#   'RN_INDI': 313232,
#   'BTH_YYYY': 1925,
#   'DTH_YYYYMM': 200802,
#   'COD1': 'I21'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7dfd'),
#   'RN_INDI': 511135,
#   'BTH_YYYY': 1926,
#   'DTH_YYYYMM': 201808,
#   'COD1': 'A00-A09'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7dfe'),
#   'RN_INDI': 734534,
#   'BTH_YYYY': 1926,
#   'DTH_YYYYMM': 201707,
#   'COD1': 'R54'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7dff'),
#   'RN_INDI': 167044,
#   'BTH_YYYY': 1927,
#   'DTH_YYYYMM': 200803,
#   'COD1': 'R54'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e00'),
#   'RN_INDI': 498406,
#   'BTH_YYYY': 1927,
#   'DTH_YYYYMM': 201012,
#   'COD1': 'F00-F09'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e01'),
#   'RN_INDI': 847594,
#   'BTH_YYYY': 1927,
#   'DTH_YYYYMM': 201010,
#   'COD1': 'C34'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e02'),
#   'RN_INDI': 924012,
#   'BTH_YYYY': 1927,
#   'DTH_YYYYMM': 201903,
#   'COD1': 'C22'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e03'),
#   'RN_INDI': 57736,
#   'BTH_YYYY': 1928,
#   'DTH_YYYYMM': 201602,
#   'COD1': 'C34'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e04'),
#   'RN_INDI': 156212,
#   'BTH_YYYY': 1928,
#   'DTH_YYYYMM': 201502,
#   'COD1': 'I64'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e05'),
#   'RN_INDI': 647502,
#   'BTH_YYYY': 1928,
#   'DTH_YYYYMM': 201511,
#   'COD1': 'C22'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e06'),
#   'RN_INDI': 776841,
#   'BTH_YYYY': 1929,
#   'DTH_YYYYMM': 201401,
#   'COD1': 'I20'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e07'),
#   'RN_INDI': 266922,
#   'BTH_YYYY': 1930},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e08'),
#   'RN_INDI': 278164,
#   'BTH_YYYY': 1930,
#   'DTH_YYYYMM': 201904,
#   'COD1': 'I63'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e09'),
#   'RN_INDI': 314204,
#   'BTH_YYYY': 1930,
#   'DTH_YYYYMM': 201109,
#   'COD1': 'I69'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e0a'),
#   'RN_INDI': 394044,
#   'BTH_YYYY': 1930,
#   'DTH_YYYYMM': 201911,
#   'COD1': 'G30'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e0b'),
#   'RN_INDI': 415031,
#   'BTH_YYYY': 1930,
#   'DTH_YYYYMM': 201311,
#   'COD1': 'C22'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e0c'),
#   'RN_INDI': 563280,
#   'BTH_YYYY': 1931},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e0d'),
#   'RN_INDI': 750849,
#   'BTH_YYYY': 1931},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e0e'),
#   'RN_INDI': 933418,
#   'BTH_YYYY': 1931},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e0f'),
#   'RN_INDI': 45815,
#   'BTH_YYYY': 1932},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e10'),
#   'RN_INDI': 60164,
#   'BTH_YYYY': 1932,
#   'DTH_YYYYMM': 201910,
#   'COD1': 'T51-T65',
#   'COD2': 'X00-X09'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e11'),
#   'RN_INDI': 217071,
#   'BTH_YYYY': 1932},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e12'),
#   'RN_INDI': 661358,
#   'BTH_YYYY': 1932},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e13'),
#   'RN_INDI': 780565,
#   'BTH_YYYY': 1932},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e14'),
#   'RN_INDI': 830395,
#   'BTH_YYYY': 1932,
#   'DTH_YYYYMM': 201909,
#   'COD1': 'J80'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e15'),
#   'RN_INDI': 845220,
#   'BTH_YYYY': 1932,
#   'DTH_YYYYMM': 201610,
#   'COD1': 'E11'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e16'),
#   'RN_INDI': 904961,
#   'BTH_YYYY': 1932,
#   'DTH_YYYYMM': 201102,
#   'COD1': 'I50'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e17'),
#   'RN_INDI': 128764,
#   'BTH_YYYY': 1933},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e18'),
#   'RN_INDI': 447304,
#   'BTH_YYYY': 1933},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e19'),
#   'RN_INDI': 661690,
#   'BTH_YYYY': 1933},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e1a'),
#   'RN_INDI': 759704,
#   'BTH_YYYY': 1933},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e1b'),
#   'RN_INDI': 817724,
#   'BTH_YYYY': 1933,
#   'DTH_YYYYMM': 200907,
#   'COD1': 'I21'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e1c'),
#   'RN_INDI': 891674,
#   'BTH_YYYY': 1933},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e1d'),
#   'RN_INDI': 35364,
#   'BTH_YYYY': 1934,
#   'DTH_YYYYMM': 201503,
#   'COD1': 'I25'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e1e'),
#   'RN_INDI': 374055,
#   'BTH_YYYY': 1934},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e1f'),
#   'RN_INDI': 732273,
#   'BTH_YYYY': 1934},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e20'),
#   'RN_INDI': 823068,
#   'BTH_YYYY': 1934,
#   'DTH_YYYYMM': 202105},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e21'),
#   'RN_INDI': 830143,
#   'BTH_YYYY': 1934},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e22'),
#   'RN_INDI': 863928,
#   'BTH_YYYY': 1934,
#   'DTH_YYYYMM': 200812,
#   'COD1': 'T08-T14',
#   'COD2': 'V20-V29'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e23'),
#   'RN_INDI': 929045,
#   'BTH_YYYY': 1934,
#   'DTH_YYYYMM': 201008,
#   'COD1': 'J60'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e24'),
#   'RN_INDI': 6088,
#   'BTH_YYYY': 1935,
#   'DTH_YYYYMM': 201610,
#   'COD1': 'I46'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e25'),
#   'RN_INDI': 286730,
#   'BTH_YYYY': 1935},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e26'),
#   'RN_INDI': 338024,
#   'BTH_YYYY': 1935,
#   'DTH_YYYYMM': 201904,
#   'COD1': 'C15'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e27'),
#   'RN_INDI': 356231,
#   'BTH_YYYY': 1935},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e28'),
#   'RN_INDI': 940080,
#   'BTH_YYYY': 1935},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e29'),
#   'RN_INDI': 451174,
#   'BTH_YYYY': 1936,
#   'DTH_YYYYMM': 201207,
#   'COD1': 'C90'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e2a'),
#   'RN_INDI': 460880,
#   'BTH_YYYY': 1936},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e2b'),
#   'RN_INDI': 752341,
#   'BTH_YYYY': 1936,
#   'DTH_YYYYMM': 201905,
#   'COD1': 'B00-B09'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e2c'),
#   'RN_INDI': 769362,
#   'BTH_YYYY': 1936},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e2d'),
#   'RN_INDI': 892931,
#   'BTH_YYYY': 1936},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e2e'),
#   'RN_INDI': 982512,
#   'BTH_YYYY': 1936,
#   'DTH_YYYYMM': 201009,
#   'COD1': 'C34'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e2f'),
#   'RN_INDI': 986085,
#   'BTH_YYYY': 1936,
#   'DTH_YYYYMM': 201212,
#   'COD1': 'J44'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e30'),
#   'RN_INDI': 121652,
#   'BTH_YYYY': 1937,
#   'DTH_YYYYMM': 202010},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e31'),
#   'RN_INDI': 211587,
#   'BTH_YYYY': 1937},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e32'),
#   'RN_INDI': 639262,
#   'BTH_YYYY': 1937,
#   'DTH_YYYYMM': 201007,
#   'COD1': 'C16'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e33'),
#   'RN_INDI': 192153,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e34'),
#   'RN_INDI': 340919,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e35'),
#   'RN_INDI': 466622,
#   'BTH_YYYY': 1938,
#   'DTH_YYYYMM': 201409,
#   'COD1': 'T15-T19',
#   'COD2': 'W75-W84'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e36'),
#   'RN_INDI': 602767,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e37'),
#   'RN_INDI': 631088,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e38'),
#   'RN_INDI': 645281,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e39'),
#   'RN_INDI': 687590,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e3a'),
#   'RN_INDI': 782784,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e3b'),
#   'RN_INDI': 785193,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e3c'),
#   'RN_INDI': 904381,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e3d'),
#   'RN_INDI': 136163,
#   'BTH_YYYY': 1939},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e3e'),
#   'RN_INDI': 678141,
#   'BTH_YYYY': 1939,
#   'DTH_YYYYMM': 201210,
#   'COD1': 'T15-T19',
#   'COD2': 'W75-W84'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e3f'),
#   'RN_INDI': 734409,
#   'BTH_YYYY': 1939,
#   'DTH_YYYYMM': 201906,
#   'COD1': 'N18'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e40'),
#   'RN_INDI': 752588,
#   'BTH_YYYY': 1939},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e41'),
#   'RN_INDI': 973001,
#   'BTH_YYYY': 1939},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e42'),
#   'RN_INDI': 202610,
#   'BTH_YYYY': 1940},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e43'),
#   'RN_INDI': 588655,
#   'BTH_YYYY': 1940,
#   'DTH_YYYYMM': 201508,
#   'COD1': 'J81'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e44'),
#   'RN_INDI': 596321,
#   'BTH_YYYY': 1940},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e45'),
#   'RN_INDI': 674283,
#   'BTH_YYYY': 1940},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e46'),
#   'RN_INDI': 773366,
#   'BTH_YYYY': 1940},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e47'),
#   'RN_INDI': 195032,
#   'BTH_YYYY': 1941},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e48'),
#   'RN_INDI': 281502,
#   'BTH_YYYY': 1941},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e49'),
#   'RN_INDI': 335999,
#   'BTH_YYYY': 1941},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e4a'),
#   'RN_INDI': 399667,
#   'BTH_YYYY': 1941},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e4b'),
#   'RN_INDI': 669847,
#   'BTH_YYYY': 1941,
#   'DTH_YYYYMM': 202011},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e4c'),
#   'RN_INDI': 874400,
#   'BTH_YYYY': 1941},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e4d'),
#   'RN_INDI': 19442,
#   'BTH_YYYY': 1942,
#   'DTH_YYYYMM': 202003},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e4e'),
#   'RN_INDI': 214085,
#   'BTH_YYYY': 1942},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e4f'),
#   'RN_INDI': 499129,
#   'BTH_YYYY': 1942},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e50'),
#   'RN_INDI': 526484,
#   'BTH_YYYY': 1942},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e51'),
#   'RN_INDI': 594404,
#   'BTH_YYYY': 1942},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e52'),
#   'RN_INDI': 777023,
#   'BTH_YYYY': 1942},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e53'),
#   'RN_INDI': 793097,
#   'BTH_YYYY': 1942},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e54'),
#   'RN_INDI': 99170,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e55'),
#   'RN_INDI': 179035,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e56'),
#   'RN_INDI': 293594,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e57'),
#   'RN_INDI': 411541,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e58'),
#   'RN_INDI': 561959,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e59'),
#   'RN_INDI': 658248,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e5a'),
#   'RN_INDI': 782489,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e5b'),
#   'RN_INDI': 905179,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e5c'),
#   'RN_INDI': 138056,
#   'BTH_YYYY': 1944},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e5d'),
#   'RN_INDI': 423141,
#   'BTH_YYYY': 1944},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e5e'),
#   'RN_INDI': 462208,
#   'BTH_YYYY': 1944},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e5f'),
#   'RN_INDI': 641654,
#   'BTH_YYYY': 1944},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e60'),
#   'RN_INDI': 652355,
#   'BTH_YYYY': 1944},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e61'),
#   'RN_INDI': 668008,
#   'BTH_YYYY': 1944,
#   'DTH_YYYYMM': 201909,
#   'COD1': 'I50'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e62'),
#   'RN_INDI': 699543,
#   'BTH_YYYY': 1944},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e63'),
#   'RN_INDI': 915167,
#   'BTH_YYYY': 1944},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e64'),
#   'RN_INDI': 267631,
#   'BTH_YYYY': 1945},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e65'),
#   'RN_INDI': 325107,
#   'BTH_YYYY': 1945},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e66'),
#   'RN_INDI': 347480,
#   'BTH_YYYY': 1945},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e67'),
#   'RN_INDI': 400685,
#   'BTH_YYYY': 1945},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e68'),
#   'RN_INDI': 434429,
#   'BTH_YYYY': 1945},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e69'),
#   'RN_INDI': 459027,
#   'BTH_YYYY': 1945},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e6a'),
#   'RN_INDI': 685794,
#   'BTH_YYYY': 1945},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e6b'),
#   'RN_INDI': 224374,
#   'BTH_YYYY': 1946},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e6c'),
#   'RN_INDI': 516621,
#   'BTH_YYYY': 1946},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e6d'),
#   'RN_INDI': 635052,
#   'BTH_YYYY': 1946},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e6e'),
#   'RN_INDI': 800215,
#   'BTH_YYYY': 1946,
#   'DTH_YYYYMM': 202103},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e6f'),
#   'RN_INDI': 838106,
#   'BTH_YYYY': 1946},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e70'),
#   'RN_INDI': 972420,
#   'BTH_YYYY': 1946},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e71'),
#   'RN_INDI': 991935,
#   'BTH_YYYY': 1946},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e72'),
#   'RN_INDI': 49564,
#   'BTH_YYYY': 1947,
#   'DTH_YYYYMM': 201509,
#   'COD1': 'C25'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e73'),
#   'RN_INDI': 73591,
#   'BTH_YYYY': 1947,
#   'DTH_YYYYMM': 202105},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e74'),
#   'RN_INDI': 459355,
#   'BTH_YYYY': 1947,
#   'DTH_YYYYMM': 200902,
#   'COD1': 'S00-S09',
#   'COD2': 'V01-V09'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e75'),
#   'RN_INDI': 557550,
#   'BTH_YYYY': 1947,
#   'DTH_YYYYMM': 202008},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e76'),
#   'RN_INDI': 618926,
#   'BTH_YYYY': 1947},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e77'),
#   'RN_INDI': 989524,
#   'BTH_YYYY': 1947},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e78'),
#   'RN_INDI': 43189,
#   'BTH_YYYY': 1948},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e79'),
#   'RN_INDI': 335758,
#   'BTH_YYYY': 1948},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e7a'),
#   'RN_INDI': 352171,
#   'BTH_YYYY': 1948,
#   'DTH_YYYYMM': 202002},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e7b'),
#   'RN_INDI': 435393,
#   'BTH_YYYY': 1948},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e7c'),
#   'RN_INDI': 557288,
#   'BTH_YYYY': 1948},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e7d'),
#   'RN_INDI': 646251,
#   'BTH_YYYY': 1948},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e7e'),
#   'RN_INDI': 794513,
#   'BTH_YYYY': 1948},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e7f'),
#   'RN_INDI': 992976,
#   'BTH_YYYY': 1948},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e80'),
#   'RN_INDI': 6091,
#   'BTH_YYYY': 1949},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e81'),
#   'RN_INDI': 174366,
#   'BTH_YYYY': 1949},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e82'),
#   'RN_INDI': 291793,
#   'BTH_YYYY': 1949},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e83'),
#   'RN_INDI': 293083,
#   'BTH_YYYY': 1949,
#   'DTH_YYYYMM': 200712,
#   'COD1': 'K70'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e84'),
#   'RN_INDI': 346560,
#   'BTH_YYYY': 1949},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e85'),
#   'RN_INDI': 400705,
#   'BTH_YYYY': 1949},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e86'),
#   'RN_INDI': 491396,
#   'BTH_YYYY': 1949},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e87'),
#   'RN_INDI': 688356,
#   'BTH_YYYY': 1949},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e88'),
#   'RN_INDI': 13486,
#   'BTH_YYYY': 1950},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e89'),
#   'RN_INDI': 77520,
#   'BTH_YYYY': 1950,
#   'DTH_YYYYMM': 201811,
#   'COD1': 'C25'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e8a'),
#   'RN_INDI': 268861,
#   'BTH_YYYY': 1950},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e8b'),
#   'RN_INDI': 391223,
#   'BTH_YYYY': 1950,
#   'DTH_YYYYMM': 202007},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e8c'),
#   'RN_INDI': 418141,
#   'BTH_YYYY': 1950},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e8d'),
#   'RN_INDI': 577109,
#   'BTH_YYYY': 1950},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e8e'),
#   'RN_INDI': 694471,
#   'BTH_YYYY': 1950},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e8f'),
#   'RN_INDI': 770773,
#   'BTH_YYYY': 1950,
#   'DTH_YYYYMM': 201806,
#   'COD1': 'E11'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e90'),
#   'RN_INDI': 26921,
#   'BTH_YYYY': 1951},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e91'),
#   'RN_INDI': 51743,
#   'BTH_YYYY': 1951},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e92'),
#   'RN_INDI': 136900,
#   'BTH_YYYY': 1951},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e93'),
#   'RN_INDI': 254163,
#   'BTH_YYYY': 1951},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e94'),
#   'RN_INDI': 513026,
#   'BTH_YYYY': 1951},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e95'),
#   'RN_INDI': 738834,
#   'BTH_YYYY': 1951},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e96'),
#   'RN_INDI': 889348,
#   'BTH_YYYY': 1951},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e97'),
#   'RN_INDI': 165492,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e98'),
#   'RN_INDI': 183863,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e99'),
#   'RN_INDI': 216674,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e9a'),
#   'RN_INDI': 326051,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e9b'),
#   'RN_INDI': 354997,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e9c'),
#   'RN_INDI': 375650,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e9d'),
#   'RN_INDI': 398604,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e9e'),
#   'RN_INDI': 414026,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7e9f'),
#   'RN_INDI': 547878,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ea0'),
#   'RN_INDI': 689623,
#   'BTH_YYYY': 1952,
#   'DTH_YYYYMM': 201110,
#   'COD1': 'J84'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ea1'),
#   'RN_INDI': 733753,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ea2'),
#   'RN_INDI': 941010,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ea3'),
#   'RN_INDI': 4392,
#   'BTH_YYYY': 1953,
#   'DTH_YYYYMM': 201204,
#   'COD1': 'N18'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ea4'),
#   'RN_INDI': 91952,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ea5'),
#   'RN_INDI': 104229,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ea6'),
#   'RN_INDI': 171740,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ea7'),
#   'RN_INDI': 317094,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ea8'),
#   'RN_INDI': 359683,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ea9'),
#   'RN_INDI': 441482,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eaa'),
#   'RN_INDI': 474187,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eab'),
#   'RN_INDI': 534288,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eac'),
#   'RN_INDI': 649286,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ead'),
#   'RN_INDI': 680896,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eae'),
#   'RN_INDI': 734772,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eaf'),
#   'RN_INDI': 778752,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eb0'),
#   'RN_INDI': 965940,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eb1'),
#   'RN_INDI': 997203,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eb2'),
#   'RN_INDI': 267582,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eb3'),
#   'RN_INDI': 366576,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eb4'),
#   'RN_INDI': 396281,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eb5'),
#   'RN_INDI': 405681,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eb6'),
#   'RN_INDI': 632149,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eb7'),
#   'RN_INDI': 744818,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eb8'),
#   'RN_INDI': 757675,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eb9'),
#   'RN_INDI': 1003337,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eba'),
#   'RN_INDI': 111233,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ebb'),
#   'RN_INDI': 184935,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ebc'),
#   'RN_INDI': 322714,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ebd'),
#   'RN_INDI': 365179,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ebe'),
#   'RN_INDI': 489958,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ebf'),
#   'RN_INDI': 526975,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ec0'),
#   'RN_INDI': 576619,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ec1'),
#   'RN_INDI': 616301,
#   'BTH_YYYY': 1955,
#   'DTH_YYYYMM': 201012,
#   'COD1': 'T66-T78',
#   'COD2': 'X60-X84'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ec2'),
#   'RN_INDI': 691360,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ec3'),
#   'RN_INDI': 698203,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ec4'),
#   'RN_INDI': 724356,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ec5'),
#   'RN_INDI': 767776,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ec6'),
#   'RN_INDI': 855875,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ec7'),
#   'RN_INDI': 961636,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ec8'),
#   'RN_INDI': 47686,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ec9'),
#   'RN_INDI': 446544,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eca'),
#   'RN_INDI': 479670,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ecb'),
#   'RN_INDI': 511798,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ecc'),
#   'RN_INDI': 534381,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ecd'),
#   'RN_INDI': 544817,
#   'BTH_YYYY': 1956,
#   'DTH_YYYYMM': 201912,
#   'COD1': 'C83'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ece'),
#   'RN_INDI': 593807,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ecf'),
#   'RN_INDI': 658643,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ed0'),
#   'RN_INDI': 712367,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ed1'),
#   'RN_INDI': 758449,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ed2'),
#   'RN_INDI': 759109,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ed3'),
#   'RN_INDI': 138777,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ed4'),
#   'RN_INDI': 190943,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ed5'),
#   'RN_INDI': 217974,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ed6'),
#   'RN_INDI': 280296,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ed7'),
#   'RN_INDI': 291326,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ed8'),
#   'RN_INDI': 326525,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ed9'),
#   'RN_INDI': 411755,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eda'),
#   'RN_INDI': 567118,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7edb'),
#   'RN_INDI': 573784,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7edc'),
#   'RN_INDI': 946035,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7edd'),
#   'RN_INDI': 953845,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ede'),
#   'RN_INDI': 996319,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7edf'),
#   'RN_INDI': 36941,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ee0'),
#   'RN_INDI': 174428,
#   'BTH_YYYY': 1958,
#   'DTH_YYYYMM': 200709,
#   'COD1': 'F10-F19'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ee1'),
#   'RN_INDI': 201324,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ee2'),
#   'RN_INDI': 312513,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ee3'),
#   'RN_INDI': 399523,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ee4'),
#   'RN_INDI': 635359,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ee5'),
#   'RN_INDI': 721929,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ee6'),
#   'RN_INDI': 783723,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ee7'),
#   'RN_INDI': 934842,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ee8'),
#   'RN_INDI': 956347,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ee9'),
#   'RN_INDI': 6907,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eea'),
#   'RN_INDI': 139052,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eeb'),
#   'RN_INDI': 150062,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eec'),
#   'RN_INDI': 255665,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eed'),
#   'RN_INDI': 302152,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eee'),
#   'RN_INDI': 323839,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eef'),
#   'RN_INDI': 362517,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ef0'),
#   'RN_INDI': 474121,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ef1'),
#   'RN_INDI': 586351,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ef2'),
#   'RN_INDI': 596632,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ef3'),
#   'RN_INDI': 741694,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ef4'),
#   'RN_INDI': 753025,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ef5'),
#   'RN_INDI': 834250,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ef6'),
#   'RN_INDI': 909636,
#   'BTH_YYYY': 1959,
#   'DTH_YYYYMM': 201608,
#   'COD1': 'N17'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ef7'),
#   'RN_INDI': 941014,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ef8'),
#   'RN_INDI': 28967,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7ef9'),
#   'RN_INDI': 45383,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7efa'),
#   'RN_INDI': 120601,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7efb'),
#   'RN_INDI': 142037,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7efc'),
#   'RN_INDI': 183094,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7efd'),
#   'RN_INDI': 237870,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7efe'),
#   'RN_INDI': 249100,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7eff'),
#   'RN_INDI': 253557,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f00'),
#   'RN_INDI': 257985,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f01'),
#   'RN_INDI': 276428,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f02'),
#   'RN_INDI': 315899,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f03'),
#   'RN_INDI': 323550,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f04'),
#   'RN_INDI': 350191,
#   'BTH_YYYY': 1960,
#   'DTH_YYYYMM': 202102},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f05'),
#   'RN_INDI': 479772,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f06'),
#   'RN_INDI': 733272,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f07'),
#   'RN_INDI': 764856,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f08'),
#   'RN_INDI': 784523,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f09'),
#   'RN_INDI': 800326,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f0a'),
#   'RN_INDI': 848771,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f0b'),
#   'RN_INDI': 849697,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f0c'),
#   'RN_INDI': 857971,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f0d'),
#   'RN_INDI': 874557,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f0e'),
#   'RN_INDI': 902791,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f0f'),
#   'RN_INDI': 933428,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f10'),
#   'RN_INDI': 62782,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f11'),
#   'RN_INDI': 181948,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f12'),
#   'RN_INDI': 213565,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f13'),
#   'RN_INDI': 272276,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f14'),
#   'RN_INDI': 272384,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f15'),
#   'RN_INDI': 280180,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f16'),
#   'RN_INDI': 417450,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f17'),
#   'RN_INDI': 607228,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f18'),
#   'RN_INDI': 629778,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f19'),
#   'RN_INDI': 643505,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f1a'),
#   'RN_INDI': 774338,
#   'BTH_YYYY': 1961,
#   'DTH_YYYYMM': 201711,
#   'COD1': 'F10-F19'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f1b'),
#   'RN_INDI': 843214,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f1c'),
#   'RN_INDI': 888311,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f1d'),
#   'RN_INDI': 899496,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f1e'),
#   'RN_INDI': 913378,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f1f'),
#   'RN_INDI': 13456,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f20'),
#   'RN_INDI': 54310,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f21'),
#   'RN_INDI': 89343,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f22'),
#   'RN_INDI': 231812,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f23'),
#   'RN_INDI': 244210,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f24'),
#   'RN_INDI': 290156,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f25'),
#   'RN_INDI': 358065,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f26'),
#   'RN_INDI': 417917,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f27'),
#   'RN_INDI': 616341,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f28'),
#   'RN_INDI': 630247,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f29'),
#   'RN_INDI': 727759,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f2a'),
#   'RN_INDI': 761432,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f2b'),
#   'RN_INDI': 784394,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f2c'),
#   'RN_INDI': 786621,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f2d'),
#   'RN_INDI': 798660,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f2e'),
#   'RN_INDI': 950140,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f2f'),
#   'RN_INDI': 8123,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f30'),
#   'RN_INDI': 64464,
#   'BTH_YYYY': 1963,
#   'DTH_YYYYMM': 201811,
#   'COD1': 'C34'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f31'),
#   'RN_INDI': 171250,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f32'),
#   'RN_INDI': 197204,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f33'),
#   'RN_INDI': 293850,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f34'),
#   'RN_INDI': 334789,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f35'),
#   'RN_INDI': 507721,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f36'),
#   'RN_INDI': 513398,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f37'),
#   'RN_INDI': 556042,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f38'),
#   'RN_INDI': 699248,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f39'),
#   'RN_INDI': 780676,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f3a'),
#   'RN_INDI': 790573,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f3b'),
#   'RN_INDI': 806729,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f3c'),
#   'RN_INDI': 866221,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f3d'),
#   'RN_INDI': 58754,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f3e'),
#   'RN_INDI': 62197,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f3f'),
#   'RN_INDI': 82185,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f40'),
#   'RN_INDI': 83610,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f41'),
#   'RN_INDI': 114351,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f42'),
#   'RN_INDI': 223544,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f43'),
#   'RN_INDI': 328999,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f44'),
#   'RN_INDI': 332538,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f45'),
#   'RN_INDI': 338796,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f46'),
#   'RN_INDI': 406502,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f47'),
#   'RN_INDI': 557653,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f48'),
#   'RN_INDI': 637891,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f49'),
#   'RN_INDI': 646640,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f4a'),
#   'RN_INDI': 777069,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f4b'),
#   'RN_INDI': 961315,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f4c'),
#   'RN_INDI': 212874,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f4d'),
#   'RN_INDI': 254322,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f4e'),
#   'RN_INDI': 436198,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f4f'),
#   'RN_INDI': 444084,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f50'),
#   'RN_INDI': 481258,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f51'),
#   'RN_INDI': 507438,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f52'),
#   'RN_INDI': 529564,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f53'),
#   'RN_INDI': 594837,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f54'),
#   'RN_INDI': 643311,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f55'),
#   'RN_INDI': 649389,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f56'),
#   'RN_INDI': 737330,
#   'BTH_YYYY': 1965,
#   'DTH_YYYYMM': 201205,
#   'COD1': 'C50'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f57'),
#   'RN_INDI': 771454,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f58'),
#   'RN_INDI': 1010728,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f59'),
#   'RN_INDI': 13228,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f5a'),
#   'RN_INDI': 93403,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f5b'),
#   'RN_INDI': 194296,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f5c'),
#   'RN_INDI': 250810,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f5d'),
#   'RN_INDI': 290097,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f5e'),
#   'RN_INDI': 327665,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f5f'),
#   'RN_INDI': 336032,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f60'),
#   'RN_INDI': 376807,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f61'),
#   'RN_INDI': 388840,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f62'),
#   'RN_INDI': 393656,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f63'),
#   'RN_INDI': 400003,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f64'),
#   'RN_INDI': 419667,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f65'),
#   'RN_INDI': 565772,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f66'),
#   'RN_INDI': 629788,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f67'),
#   'RN_INDI': 678128,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f68'),
#   'RN_INDI': 683071,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f69'),
#   'RN_INDI': 727629,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f6a'),
#   'RN_INDI': 879081,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f6b'),
#   'RN_INDI': 967749,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f6c'),
#   'RN_INDI': 60947,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f6d'),
#   'RN_INDI': 123392,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f6e'),
#   'RN_INDI': 137557,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f6f'),
#   'RN_INDI': 233697,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f70'),
#   'RN_INDI': 245082,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f71'),
#   'RN_INDI': 286410,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f72'),
#   'RN_INDI': 305719,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f73'),
#   'RN_INDI': 440063,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f74'),
#   'RN_INDI': 490275,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f75'),
#   'RN_INDI': 503543,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f76'),
#   'RN_INDI': 506073,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f77'),
#   'RN_INDI': 552401,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f78'),
#   'RN_INDI': 582426,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f79'),
#   'RN_INDI': 622548,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f7a'),
#   'RN_INDI': 689166,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f7b'),
#   'RN_INDI': 752392,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f7c'),
#   'RN_INDI': 794554,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f7d'),
#   'RN_INDI': 817856,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f7e'),
#   'RN_INDI': 834908,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f7f'),
#   'RN_INDI': 846679,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f80'),
#   'RN_INDI': 959064,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f81'),
#   'RN_INDI': 6616,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f82'),
#   'RN_INDI': 17781,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f83'),
#   'RN_INDI': 74642,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f84'),
#   'RN_INDI': 113162,
#   'BTH_YYYY': 1968,
#   'DTH_YYYYMM': 201508,
#   'COD1': 'K70'},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f85'),
#   'RN_INDI': 158220,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f86'),
#   'RN_INDI': 170619,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f87'),
#   'RN_INDI': 187296,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f88'),
#   'RN_INDI': 297639,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f89'),
#   'RN_INDI': 376684,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f8a'),
#   'RN_INDI': 414618,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f8b'),
#   'RN_INDI': 417458,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f8c'),
#   'RN_INDI': 439422,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f8d'),
#   'RN_INDI': 492073,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f8e'),
#   'RN_INDI': 553458,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f8f'),
#   'RN_INDI': 554157,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f90'),
#   'RN_INDI': 559413,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f91'),
#   'RN_INDI': 560319,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f92'),
#   'RN_INDI': 565652,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f93'),
#   'RN_INDI': 655520,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f94'),
#   'RN_INDI': 700176,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f95'),
#   'RN_INDI': 745298,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f96'),
#   'RN_INDI': 780304,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f97'),
#   'RN_INDI': 795056,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f98'),
#   'RN_INDI': 815235,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f99'),
#   'RN_INDI': 89809,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f9a'),
#   'RN_INDI': 127572,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f9b'),
#   'RN_INDI': 163932,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f9c'),
#   'RN_INDI': 176697,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f9d'),
#   'RN_INDI': 213984,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f9e'),
#   'RN_INDI': 241985,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7f9f'),
#   'RN_INDI': 285810,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fa0'),
#   'RN_INDI': 313646,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fa1'),
#   'RN_INDI': 328638,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fa2'),
#   'RN_INDI': 350246,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fa3'),
#   'RN_INDI': 442751,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fa4'),
#   'RN_INDI': 466008,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fa5'),
#   'RN_INDI': 485457,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fa6'),
#   'RN_INDI': 505466,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fa7'),
#   'RN_INDI': 533519,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fa8'),
#   'RN_INDI': 638590,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fa9'),
#   'RN_INDI': 646093,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7faa'),
#   'RN_INDI': 828266,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fab'),
#   'RN_INDI': 905465,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fac'),
#   'RN_INDI': 933678,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fad'),
#   'RN_INDI': 1000068,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fae'),
#   'RN_INDI': 85360,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7faf'),
#   'RN_INDI': 92707,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fb0'),
#   'RN_INDI': 253233,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fb1'),
#   'RN_INDI': 262759,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fb2'),
#   'RN_INDI': 332455,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fb3'),
#   'RN_INDI': 481221,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fb4'),
#   'RN_INDI': 561326,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fb5'),
#   'RN_INDI': 604549,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fb6'),
#   'RN_INDI': 639227,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fb7'),
#   'RN_INDI': 677413,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fb8'),
#   'RN_INDI': 843082,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fb9'),
#   'RN_INDI': 905593,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fba'),
#   'RN_INDI': 913018,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fbb'),
#   'RN_INDI': 932986,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fbc'),
#   'RN_INDI': 8651,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fbd'),
#   'RN_INDI': 14754,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fbe'),
#   'RN_INDI': 53861,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fbf'),
#   'RN_INDI': 62118,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fc0'),
#   'RN_INDI': 172716,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fc1'),
#   'RN_INDI': 182649,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fc2'),
#   'RN_INDI': 241974,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fc3'),
#   'RN_INDI': 262509,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fc4'),
#   'RN_INDI': 312669,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fc5'),
#   'RN_INDI': 315946,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fc6'),
#   'RN_INDI': 367659,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fc7'),
#   'RN_INDI': 378613,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fc8'),
#   'RN_INDI': 413591,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fc9'),
#   'RN_INDI': 488703,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fca'),
#   'RN_INDI': 545148,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fcb'),
#   'RN_INDI': 607798,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fcc'),
#   'RN_INDI': 822808,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fcd'),
#   'RN_INDI': 961069,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fce'),
#   'RN_INDI': 970269,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fcf'),
#   'RN_INDI': 55619,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fd0'),
#   'RN_INDI': 92721,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fd1'),
#   'RN_INDI': 98010,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fd2'),
#   'RN_INDI': 412233,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fd3'),
#   'RN_INDI': 439222,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fd4'),
#   'RN_INDI': 449936,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fd5'),
#   'RN_INDI': 561313,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fd6'),
#   'RN_INDI': 605092,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fd7'),
#   'RN_INDI': 665753,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fd8'),
#   'RN_INDI': 731675,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fd9'),
#   'RN_INDI': 757190,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fda'),
#   'RN_INDI': 826718,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fdb'),
#   'RN_INDI': 996207,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fdc'),
#   'RN_INDI': 203261,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fdd'),
#   'RN_INDI': 306433,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fde'),
#   'RN_INDI': 385559,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fdf'),
#   'RN_INDI': 416604,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fe0'),
#   'RN_INDI': 527979,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fe1'),
#   'RN_INDI': 739343,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fe2'),
#   'RN_INDI': 783799,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fe3'),
#   'RN_INDI': 828317,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fe4'),
#   'RN_INDI': 841175,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fe5'),
#   'RN_INDI': 986005,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fe6'),
#   'RN_INDI': 1004971,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fe7'),
#   'RN_INDI': 51105,
#   'BTH_YYYY': 1974},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fe8'),
#   'RN_INDI': 176242,
#   'BTH_YYYY': 1974},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fe9'),
#   'RN_INDI': 203402,
#   'BTH_YYYY': 1974},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fea'),
#   'RN_INDI': 349647,
#   'BTH_YYYY': 1974},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7feb'),
#   'RN_INDI': 420854,
#   'BTH_YYYY': 1974},
#  {'_id': ObjectId('64d2fd08ec72f175b12b7fec'),
#   'RN_INDI': 423842,
#   'BTH_YYYY': 1974},
# ...
#   'RN_INDI': 971748,
#   'BTH_YYYY': 1997},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8128'),
#   'RN_INDI': 225503,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8129'),
#   'RN_INDI': 269902,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd08ec72f175b12b812a'),
#   'RN_INDI': 302781,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd08ec72f175b12b812b'),
#   'RN_INDI': 326883,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd08ec72f175b12b812c'),
#   'RN_INDI': 335411,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd08ec72f175b12b812d'),
#   'RN_INDI': 468958,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd08ec72f175b12b812e'),
#   'RN_INDI': 539874,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd08ec72f175b12b812f'),
#   'RN_INDI': 695844,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8130'),
#   'RN_INDI': 787867,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8131'),
#   'RN_INDI': 806727,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8132'),
#   'RN_INDI': 905339,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8133'),
#   'RN_INDI': 916359,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8134'),
#   'RN_INDI': 951174,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8135'),
#   'RN_INDI': 73610,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8136'),
#   'RN_INDI': 163969,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8137'),
#   'RN_INDI': 179020,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8138'),
#   'RN_INDI': 238712,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8139'),
#   'RN_INDI': 308173,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd08ec72f175b12b813a'),
#   'RN_INDI': 310621,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd08ec72f175b12b813b'),
#   'RN_INDI': 425871,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd08ec72f175b12b813c'),
#   'RN_INDI': 486937,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd08ec72f175b12b813d'),
#   'RN_INDI': 563494,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd08ec72f175b12b813e'),
#   'RN_INDI': 760126,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd08ec72f175b12b813f'),
#   'RN_INDI': 879593,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8140'),
#   'RN_INDI': 82310,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8141'),
#   'RN_INDI': 84893,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8142'),
#   'RN_INDI': 161487,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8143'),
#   'RN_INDI': 176406,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8144'),
#   'RN_INDI': 257664,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8145'),
#   'RN_INDI': 466981,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8146'),
#   'RN_INDI': 577639,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8147'),
#   'RN_INDI': 708939,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8148'),
#   'RN_INDI': 753723,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8149'),
#   'RN_INDI': 813440,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd08ec72f175b12b814a'),
#   'RN_INDI': 941612,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd08ec72f175b12b814b'),
#   'RN_INDI': 950411,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd08ec72f175b12b814c'),
#   'RN_INDI': 20218,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd08ec72f175b12b814d'),
#   'RN_INDI': 49262,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd08ec72f175b12b814e'),
#   'RN_INDI': 134908,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd08ec72f175b12b814f'),
#   'RN_INDI': 158558,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8150'),
#   'RN_INDI': 208900,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8151'),
#   'RN_INDI': 250136,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8152'),
#   'RN_INDI': 263640,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8153'),
#   'RN_INDI': 273079,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8154'),
#   'RN_INDI': 396613,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8155'),
#   'RN_INDI': 413012,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8156'),
#   'RN_INDI': 519015,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8157'),
#   'RN_INDI': 546675,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8158'),
#   'RN_INDI': 561648,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8159'),
#   'RN_INDI': 864522,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd08ec72f175b12b815a'),
#   'RN_INDI': 870877,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd08ec72f175b12b815b'),
#   'RN_INDI': 899365,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd08ec72f175b12b815c'),
#   'RN_INDI': 3085,
#   'BTH_YYYY': 2002},
#  {'_id': ObjectId('64d2fd08ec72f175b12b815d'),
#   'RN_INDI': 299738,
#   'BTH_YYYY': 2002},
#  {'_id': ObjectId('64d2fd08ec72f175b12b815e'),
#   'RN_INDI': 364349,
#   'BTH_YYYY': 2002},
#  {'_id': ObjectId('64d2fd08ec72f175b12b815f'),
#   'RN_INDI': 404279,
#   'BTH_YYYY': 2002},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8160'),
#   'RN_INDI': 716015,
#   'BTH_YYYY': 2002},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8161'),
#   'RN_INDI': 802803,
#   'BTH_YYYY': 2002},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8162'),
#   'RN_INDI': 938422,
#   'BTH_YYYY': 2002},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8163'),
#   'RN_INDI': 5835,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8164'),
#   'RN_INDI': 18010,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8165'),
#   'RN_INDI': 92285,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8166'),
#   'RN_INDI': 161387,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8167'),
#   'RN_INDI': 170806,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8168'),
#   'RN_INDI': 221998,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8169'),
#   'RN_INDI': 314923,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd08ec72f175b12b816a'),
#   'RN_INDI': 601775,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd08ec72f175b12b816b'),
#   'RN_INDI': 631006,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd08ec72f175b12b816c'),
#   'RN_INDI': 636187,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd08ec72f175b12b816d'),
#   'RN_INDI': 863171,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd08ec72f175b12b816e'),
#   'RN_INDI': 963693,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd08ec72f175b12b816f'),
#   'RN_INDI': 28170,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8170'),
#   'RN_INDI': 325390,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8171'),
#   'RN_INDI': 440692,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8172'),
#   'RN_INDI': 645066,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8173'),
#   'RN_INDI': 744544,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8174'),
#   'RN_INDI': 759439,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8175'),
#   'RN_INDI': 772460,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8176'),
#   'RN_INDI': 973079,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8177'),
#   'RN_INDI': 151244,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8178'),
#   'RN_INDI': 248794,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8179'),
#   'RN_INDI': 300615,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd08ec72f175b12b817a'),
#   'RN_INDI': 314882,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd08ec72f175b12b817b'),
#   'RN_INDI': 398665,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd08ec72f175b12b817c'),
#   'RN_INDI': 407118,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd08ec72f175b12b817d'),
#   'RN_INDI': 658189,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd08ec72f175b12b817e'),
#   'RN_INDI': 658751,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd08ec72f175b12b817f'),
#   'RN_INDI': 758751,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8180'),
#   'RN_INDI': 847505,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8181'),
#   'RN_INDI': 911175,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8182'),
#   'RN_INDI': 2086938,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8183'),
#   'RN_INDI': 2086947,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8184'),
#   'RN_INDI': 2086957,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8185'),
#   'RN_INDI': 2087001,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8186'),
#   'RN_INDI': 2087359,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8187'),
#   'RN_INDI': 2088391,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8188'),
#   'RN_INDI': 2088649,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8189'),
#   'RN_INDI': 2089304,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd08ec72f175b12b818a'),
#   'RN_INDI': 2089654,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd08ec72f175b12b818b'),
#   'RN_INDI': 2089788,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd08ec72f175b12b818c'),
#   'RN_INDI': 2092954,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd08ec72f175b12b818d'),
#   'RN_INDI': 2000020,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd08ec72f175b12b818e'),
#   'RN_INDI': 2010719,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd08ec72f175b12b818f'),
#   'RN_INDI': 2018681,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8190'),
#   'RN_INDI': 2018912,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8191'),
#   'RN_INDI': 2020810,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8192'),
#   'RN_INDI': 2026212,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8193'),
#   'RN_INDI': 2042563,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8194'),
#   'RN_INDI': 2042976,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8195'),
#   'RN_INDI': 2072334,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8196'),
#   'RN_INDI': 2077234,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8197'),
#   'RN_INDI': 2078627,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8198'),
#   'RN_INDI': 2083536,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd08ec72f175b12b8199'),
#   'RN_INDI': 2029345,
#   'BTH_YYYY': 2008},
#  {'_id': ObjectId('64d2fd08ec72f175b12b819a'),
#   'RN_INDI': 2032575,
#   'BTH_YYYY': 2008},
#  {'_id': ObjectId('64d2fd08ec72f175b12b819b'),
#   'RN_INDI': 2035362,
#   'BTH_YYYY': 2008},
#  {'_id': ObjectId('64d2fd08ec72f175b12b819c'),
#   'RN_INDI': 2040013,
#   'BTH_YYYY': 2008},
#  {'_id': ObjectId('64d2fd08ec72f175b12b819d'),
#   'RN_INDI': 2061761,
#   'BTH_YYYY': 2008},
#  {'_id': ObjectId('64d2fd08ec72f175b12b819e'),
#   'RN_INDI': 2071250,
#   'BTH_YYYY': 2008},
#  {'_id': ObjectId('64d2fd08ec72f175b12b819f'),
#   'RN_INDI': 2084440,
#   'BTH_YYYY': 2008},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81a0'),
#   'RN_INDI': 2018134,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81a1'),
#   'RN_INDI': 2023673,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81a2'),
#   'RN_INDI': 2038651,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81a3'),
#   'RN_INDI': 2040254,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81a4'),
#   'RN_INDI': 2058808,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81a5'),
#   'RN_INDI': 2061873,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81a6'),
#   'RN_INDI': 2064588,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81a7'),
#   'RN_INDI': 2080462,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81a8'),
#   'RN_INDI': 2080886,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81a9'),
#   'RN_INDI': 2003497,
#   'BTH_YYYY': 2010},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81aa'),
#   'RN_INDI': 2007534,
#   'BTH_YYYY': 2010},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81ab'),
#   'RN_INDI': 2013766,
#   'BTH_YYYY': 2010},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81ac'),
#   'RN_INDI': 2022479,
#   'BTH_YYYY': 2010},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81ad'),
#   'RN_INDI': 2043266,
#   'BTH_YYYY': 2010},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81ae'),
#   'RN_INDI': 2070235,
#   'BTH_YYYY': 2010},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81af'),
#   'RN_INDI': 2075679,
#   'BTH_YYYY': 2010},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81b0'),
#   'RN_INDI': 2011515,
#   'BTH_YYYY': 2011},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81b1'),
#   'RN_INDI': 2026146,
#   'BTH_YYYY': 2011},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81b2'),
#   'RN_INDI': 2048842,
#   'BTH_YYYY': 2011},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81b3'),
#   'RN_INDI': 2052260,
#   'BTH_YYYY': 2011},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81b4'),
#   'RN_INDI': 2058256,
#   'BTH_YYYY': 2011},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81b5'),
#   'RN_INDI': 2060095,
#   'BTH_YYYY': 2011},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81b6'),
#   'RN_INDI': 2061241,
#   'BTH_YYYY': 2011},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81b7'),
#   'RN_INDI': 2019267,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81b8'),
#   'RN_INDI': 2024260,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81b9'),
#   'RN_INDI': 2029436,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81ba'),
#   'RN_INDI': 2042518,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81bb'),
#   'RN_INDI': 2045636,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81bc'),
#   'RN_INDI': 2062864,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81bd'),
#   'RN_INDI': 2066728,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81be'),
#   'RN_INDI': 2078794,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81bf'),
#   'RN_INDI': 3000357,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81c0'),
#   'RN_INDI': 2000846,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81c1'),
#   'RN_INDI': 2004812,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81c2'),
#   'RN_INDI': 2007337,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81c3'),
#   'RN_INDI': 2018770,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81c4'),
#   'RN_INDI': 2020718,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81c5'),
#   'RN_INDI': 2037391,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81c6'),
#   'RN_INDI': 2037727,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81c7'),
#   'RN_INDI': 2062330,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81c8'),
#   'RN_INDI': 2073308,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81c9'),
#   'RN_INDI': 2074479,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81ca'),
#   'RN_INDI': 2002123,
#   'BTH_YYYY': 2014},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81cb'),
#   'RN_INDI': 2002417,
#   'BTH_YYYY': 2014},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81cc'),
#   'RN_INDI': 2041982,
#   'BTH_YYYY': 2014},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81cd'),
#   'RN_INDI': 2044310,
#   'BTH_YYYY': 2014},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81ce'),
#   'RN_INDI': 2063620,
#   'BTH_YYYY': 2014},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81cf'),
#   'RN_INDI': 2070327,
#   'BTH_YYYY': 2014},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81d0'),
#   'RN_INDI': 2080025,
#   'BTH_YYYY': 2014,
#   'DTH_YYYYMM': 202004},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81d1'),
#   'RN_INDI': 2084429,
#   'BTH_YYYY': 2014},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81d2'),
#   'RN_INDI': 2037151,
#   'BTH_YYYY': 2015},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81d3'),
#   'RN_INDI': 2040322,
#   'BTH_YYYY': 2015},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81d4'),
#   'RN_INDI': 2048579,
#   'BTH_YYYY': 2015},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81d5'),
#   'RN_INDI': 2057743,
#   'BTH_YYYY': 2015},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81d6'),
#   'RN_INDI': 2063541,
#   'BTH_YYYY': 2015},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81d7'),
#   'RN_INDI': 2070251,
#   'BTH_YYYY': 2015},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81d8'),
#   'RN_INDI': 2077125,
#   'BTH_YYYY': 2015},
#  {'_id': ObjectId('64d2fd08ec72f175b12b81d9'),
#   'RN_INDI': 3000758,
#   'BTH_YYYY': 2015}]

# %%
df_BND = pd.DataFrame(list_BND)

# %%
df_BND
# Out:
#                           _id  RN_INDI BTH_YYYY  DTH_YYYYMM     COD1     COD2
# 0    64d2fd08ec72f175b12b7df2   294364   1921LE    200707.0  T08-T14  W00-W19
# 1    64d2fd08ec72f175b12b7df3   646257   1921LE    200805.0  A15-A19      NaN
# 2    64d2fd08ec72f175b12b7df4   733575   1921LE    201309.0      G30      NaN
# 3    64d2fd08ec72f175b12b7df5   966199   1921LE    201409.0      J69      NaN
# 4    64d2fd08ec72f175b12b7df6   972598   1921LE    201205.0      C44      NaN
# ..                        ...      ...      ...         ...      ...      ...
# 995  64d2fd08ec72f175b12b81d5  2057743     2015         NaN      NaN      NaN
# 996  64d2fd08ec72f175b12b81d6  2063541     2015         NaN      NaN      NaN
# 997  64d2fd08ec72f175b12b81d7  2070251     2015         NaN      NaN      NaN
# 998  64d2fd08ec72f175b12b81d8  2077125     2015         NaN      NaN      NaN
# 999  64d2fd08ec72f175b12b81d9  3000758     2015         NaN      NaN      NaN
#
# [1000 rows x 6 columns]

# %%
df_BND.to_csv('./NSC2_BND.csv')
