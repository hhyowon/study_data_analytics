),
#   'STD_YYYY': 2015,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c38522c'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 17781,
#   'SEX': 2,
#   'SGG': 41135,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c38522d'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 17781,
#   'SEX': 2,
#   'SGG': 41135,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c38522e'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 17781,
#   'SEX': 2,
#   'SGG': 41135,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c38522f'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 17781,
#   'SEX': 2,
#   'SGG': 41135,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c385230'),
#   'STD_YYYY': 2006,
# ...
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854b6'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 82310,
#   'SEX': 2,
#   'SGG': 11740,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854b7'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854b8'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854b9'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854ba'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854bb'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854bc'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854bd'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854be'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854bf'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854c0'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48125,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854c1'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48125,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854c2'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48125,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854c3'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48125,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854c4'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48125,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854c5'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854c6'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854c7'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854c8'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854c9'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854ca'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854cb'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854cc'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854cd'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854ce'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854cf'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854d0'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 44270,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854d1'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 44270,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854d2'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 44270,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854d3'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854d4'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854d5'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854d6'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854d7'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854d8'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854d9'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854da'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854db'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854dc'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854dd'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854de'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854df'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854e0'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43112,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854e1'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 28170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854e2'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 28170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854e3'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 28170,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854e4'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 28170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854e5'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 28170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854e6'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854e7'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854e8'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854e9'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854ea'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854eb'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854ec'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854ed'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854ee'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854ef'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854f0'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854f1'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854f2'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854f3'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854f4'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854f5'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854f6'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854f7'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854f8'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854f9'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854fa'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854fb'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854fc'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854fd'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854fe'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c3854ff'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c385500'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c385501'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c385502'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c385503'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c385504'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c385505'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c385506'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c385507'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c385508'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c385509'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c38550a'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c38550b'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 89809,
#   'SEX': 2,
#   'SGG': 30170,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c38550c'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 89809,
#   'SEX': 2,
#   'SGG': 30170,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311a6448fa65c7c38550d'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 89809,
#   'SEX': 2,
#   'SGG': 30170,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  ...]

# %%
df_BND = pd.DataFrame(list_BND)

# %%
df_BND
# Out:
#                             _id  STD_YYYY  RN_INDI  SEX    SGG  GAIBJA_TYPE  \
# 0      64d311a6448fa65c7c385126      2002     1433    1  29140            7
# 1      64d311a6448fa65c7c385127      2003     1433    1  29140            7
# 2      64d311a6448fa65c7c385128      2004     1433    1  29140            7
# 3      64d311a6448fa65c7c385129      2005     1433    1  29140            7
# 4      64d311a6448fa65c7c38512a      2006     1433    1  29140            7
# ...                         ...       ...      ...  ...    ...          ...
# 13022  64d311a7448fa65c7c388404      2012  3000357    2  28237            6
# 13023  64d311a7448fa65c7c388405      2013  3000357    2  28245            2
# 13024  64d311a7448fa65c7c388406      2014  3000357    2  28245            2
# 13025  64d311a7448fa65c7c388407      2015  3000357    2  28245            2
# 13026  64d311a7448fa65c7c388408      2015  3000758    1  41287            6
#
#        SMPL_TYPE_CD  CTRB_Q10 G1E_OBJ_YN  DSB_TYPE_CD  DSB_SVRT_CD_V2
# 0                 1       NaN        NaN          NaN             NaN
# 1                 1       NaN        NaN          NaN             NaN
# 2                 1       NaN        NaN          NaN             NaN
# 3                 1       NaN        NaN          NaN             NaN
# 4                 1       NaN        NaN          NaN             NaN
# ...             ...       ...        ...          ...             ...
# 13022             4       NaN        NaN          NaN             NaN
# 13023             4       6.0        NaN          NaN             NaN
# 13024             4       6.0        NaN          NaN             NaN
# 13025             4       7.0        NaN          NaN             NaN
# 13026             4       NaN        NaN          NaN             NaN
#
# [13027 rows x 11 columns]

# %%
df_BND.to_csv('./NSC2_BNC_V2_1.csv')
